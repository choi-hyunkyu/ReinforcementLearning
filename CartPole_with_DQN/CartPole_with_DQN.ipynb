# %% [markdown]
# ## Deep Q-learning
#
# 클래스를 정의해서 CartPole을 구현한다.
#
# * ReplayMemory
#
#     transition을 저장하기 위한 메모리 클래스
#
#
# * Agent
#
#     CartPole의 수레에 해당
#     update_Q_function과 get_action의 메서드를 가지고 있음
#     Brain 클래스 객체를 멤버 변수로 가짐
#
#
# * Brain
#
#     Agent 클래스의 두뇌 역할
#     딥러닝이 적용되는 부분이 Brain 부분
#     Q 테이블을 이용해 Q-learning이 구현됨
#     bins, digitize_state, update_Q_table, decide_action의 메서드를 가지고 있음
#     bins, digitize_state: Agent가 관측한 생태 observation을 이산 변수로 변환
#
#
# * Environment
#
#     OpenAI Gym이 실행되는 실행 환경
#     CartPole을 실행하며 실행을 맡을 run 메서드를 가지고 있음
#
# Agent와 Brain을 별도의 클래스로 분리한 것은 딥러닝에서 Brain 클래스로 국한되기 때문이다.

# %% [markdown]
# ## 구현 과정
#
# * ReplayMemory 정의
#
#     mini-batch 학습에서 학습된 데이터를 저장하는 역할을 할 ReplayMemory 클래스를 정의한다. ReplayMomory 클래스는 각 단계에서 해당 단계의 trainsition을 저장하는 push 메서드와 무작위로 선택된 transition을 꺼내오는 sample 메서드를 갖추고 있다. 그리고 len 메서드를 통해 현재 저장하고 있는 transition의 개수를 알려준다. 이 클래스는 저장된 transition의 개수가 capacity를 초과하면 오래된 것부터 지우고 transition의 인덱스를 새로운 transition에 부여한다.
#
#
# * Action 결정 (Agent -> Brain -> Agent)
#
#     * 행동을 결정하기 위해 Agent는 현재 상태 observation_t를 Brain 클래스에 전달한다.
#
#     * Brain 클래스는 전달받은 상태변수를 이산변수로 변환한 다음 Q_table을 참조해서 행동을 결정한다
#
#     * 결정된 현재 행동 action_t를 Agent에 전달한다.
#
#
# * Action 실행 (Agent -> Environment -> Agent)
#
#     * Agent는 Environment에 행동 action_t를 전달하며 Action을 취한 다음 Environment를 한 단계 진행시킨다.
#
#     * Environment는 다시 행동 action_t를 실행한 결과가 되는 상태 observation_t+1과 이때 얻은 즉각보상 reward_t+1을 Agent에 반환한다.
#
#
# * Q_table 수정 (Agent -> Brain)
#
#     * Agent는 현재 상태 observation_t, 조금 전 취했던 행동 action_t, 행동의 결과로 얻은 새로운 상태 observation_t+1과 받게된 즉각보상 reward_t+1 네 개의 변수를 Brain에 전달한다.
#     * Brain은 전달받은 변수를 통해 기존의 Q_table을 수정한다.
#     * observation_t, action_t, observation_t+1, reward_t+1 네 개의 변수를 합쳐놓은 것을 'Transition'이라고 부른다.
#
#
# Action 결정, Action 실행, Q_table 수정과 같이 세부과정을 포함한 총 세 개의 절차를 반복하며 Q_learning이 수행된다.

# %% [markdown]
# #

# %% [markdown]
# ## DQN 구현

# %%
import numpy as np
import matplotlib.pyplot as plt
import gym

# %matplotlib inline

# %%
'''
애니메이션 함수 정의
'''

from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

def display_frames_as_gif(frames):
    
    plt.figure(figsize = (frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(
        plt.gcf(), 
        animate, 
        frames = len(frames), 
        interval = 50
    )
    
    anim.save('CartPole_Q-learning_DQN.gif')
    display(display_animation(anim, default_mode = 'loop'))

# %%
'''
namedtuple 정의
'''

from collections import namedtuple

Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
'''
상수 정의
'''

# 태스크 네임
ENV = 'CartPole-v0'

# 각 상태를 이산변수로 변환할 구간 수
num_digitized = 6

# 시간할인율
gamma = 0.99 

# Epoch당 최대 단계 수
# CartPole-v0은 200단계를 버티면 클리어로 간주
max_steps = 200

# 최대 Epoch
nb_epochs = 1000

# batch size
batch_size = 32

# 메모리 최대 저장 수
capacity = 10000

# %%
'''
ReplayMemory 클래스 구현
'''

class ReplayMemory:
    
    def __init__(self, capacity):
        
        # 메모리 최대 저장 수
        self.capacity = capacity
        
        # 실제 transition을 저장할 변수
        self.memory = []
        
        # 저장 위치를 가리킬 인덱스 변수
        self.index = 0
        
    # transition = (state, action, state_next, reward)를 메모리에 저장
    def push(self, state, action, state_next, reward):
        
        if len(self.memory) < self.capacity:
            
            # 메모리가 여유로운 경우
            self.memory.append(None)
            
        # Transition이라는 namedtuple을 사용해 key-value 쌍의 형태로 출력을 저장
        self.memory[self.index] = Transition(state, action, state_next, reward)
        
        # 다음에 저장할 위치를 한 자리 뒤로 수정
        self.index = (self.index + 1) % self.capacity
    
    # batch_size 만큼 무작위로 저장된 transition을 추출
    def sample(self, batch_size):
        
        return random.sample(self.memory, batch_size)
    
    # __len__() 함수로 현재 저장된 transition의 개수를 반환
    def __len__(self):
        
        return len(self.memory)

# %%
'''
Agent 클래스 구현

생성자 메서드인 __init__()에서 상태변수의 수와 행동의 가짓수를 전달받고, 두뇌 역할을 할 Brain 클래스의 인스턴스를 만든다.
'''

# 실제 Agent의 역할을 하는 클래스
class Agent:
    
    def __init__(self, num_states, num_actions):
        
        # Agent의 행동을 결정하는 두뇌 역할 (Brain class 참조)
        self.brain = Brain(num_states, num_actions)
        
    def update_Q_function(self):
        
        # Brain에 전달 및 Q_table 수정 (Brain class 참조)
        self.brain.replay()
        
    def get_action(self, state, step):
        
        # 행동 결정 (Brain class 참조)
        action = self.brain.decide_action(state, step)
        
        return action
    
    # memory 인스턴스에 state, action, state_next, reward를 저장
    def memorize(self, state, action, state_next, reward):
        
        self.brain.memory.push(state, action, state_next, reward)

# %%
'''
Brain 클래스 구현

replay 메서드에서 Q_table을 신경망을 통해 수정하는 방법과 
device_action 메서드에서 다음 행동을 결정하는 방법은 epsilon-greedy 알고리즘을 이용하여 구현한다.

replay 메서드 역할
    1. 저장된 transition의 수를 확인
    2. mini-batch 생성
    3. 정답신호로 사용할 Q(s(t), a(t)) 계산
    4. 결합 가중치 수정
'''

import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F


# Agent의 두뇌 역할을 하는 클래스
class Brain:
    
    def __init__(self, num_states, num_actions):
        
        # 행동의 가짓수(왼쪽, 오른쪽)를 구함
        self.num_actions = num_actions
        
        # transition을 기억하기 위한 메모리 인스턴스 생성
        self.memory = ReplayMemory(capacity)
        
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))
        
        # 신경망 구조출력
        print(self.model)
        
        # optimizer
        learning_rate = 0.0001
        self.optimizer = optim.Adam(self.model.parameters(), lr = learning_rate)
    
    # Experience Replay로 신경망 결합 가중치 학습
    def replay(self):
        
        # 저장된 transition의 수가 미니배치 크기보다 작으면 아무 것도 하지 않음
        if len(self.memory) < batch_size:
            return
        
        # 메모리 인스턴스에서 미니배치 추출
        transition = self.memory.sample(batch_size)
        
        # 각 변수를 미니배치에 맞는 형태로 변환
        # transition은 각 단계 별로 (state, action, state_next, reward) 형태로 batch_size 만큼 저장
        # (state, action, state_next, reward) * batch_size -> (state*batch_size, action*batch_size, state_next*batch_size, reward*batch_size)
        batch = Transition(*zip(*transition))
        
        # 각 변수의 요소를 미니배치에 맞게 변형한다.
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        
        # 상태, 행동, 보상, non_final 상태로 된 미니배치를 나타내는 Variable을 생성
        non_final_next_states = torch.cat( [ s for s in batch.next_state if s is not None ] )
        
        # 신경망을 evaluation으로 변경
        self.model.eval()
        
        # self.model(state_batch)는 왼쪽, 오른쪽에 대한 Q값을 출력
        # [torch.FloatTensor of size batch_size * 2]의 형태
        # 실행한 행동 a(t)에 대한 Q값을 계산하기 때문에 
            # action_batch에서 취한 행동 a(t)가 왼쪽, 오른쪽인지에 대한 인덱스를 구하고 이에 대한 Q값을 gather 메서드로 모아온다
        state_action_values = self.model(state_batch).gather(1, action_batch)
        
        # max{Q(s_t+1, a)}값을 계산, 이때 다음 상태가 존재하는지 주의
        # CartPole이 done 상태가 아니고 next_state가 존재하는지 확인하는 인덱스 마스크 생성
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        
        # 전체 초기화
        next_state_values = torch.zeros(batch_size)
        
        # 다음 상태가 있는 인덱스에 대한 최개 Q값을 계산
        # 출력값에 접근하여 열 방향 최대값(max(1))이 되는 [값, 인덱스]를 구함
        # Q값(인덱스 0)을 출력
        # detach() 메서드로 Q값을 가져옴
        next_state_values[non_final_mask] = self.model(non_final_next_states).max(1)[0].detach()
        
        # Q(s(t), a(t))를 Q-learning으로 계산
        expected_state_action_values = reward_batch + gamma * next_state_values
        
        # 신경망을 train으로 변경
        self.model.train()
        
        # loss function은 Huber function 사용
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        
        # 경사 초기화
        self.optimizer.zero_grad()
        
        # 역전파
        loss.backward()
        
        # 가중치 수정
        self.optimizer.step()
        
    def decide_action(self, state, epoch):
        
        # epsilon-greedy 알고리즘 사용, 최적화된 행동의 비중을 증가시킴
        epsilon = 0.5 * (1 / ( epoch + 1) )
        
        if epsilon <= np.random.uniform(0, 1):
            
            # 신경망을 evaluation 모드로 변경
            self.model.eval()
            
            with torch.no_grad():
                
                # 신경망 출력의 최댓값에 대한 인덱스 = max(1)[1]
                # .view(1,1)은 [torch.LongTensor of size 1] 을 size 1*1로 변환하는 역할을 한다
                action = self.model(state).max(1)[1].view(1, 1)
                
        else:
            
            # 행동을 무작위로 반환 (0 또는 1)
            # action은 [torch.LongTensor of size 1*1] 형태가 된다
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
            
        return action

# %%
'''
Environment 클래스 구현
'''

# OpenAI Gym이 실행되는 실행 환경 CartPole을 실행
class Environment:
    
    def __init__(self):
        
        # 실행할 태스크 설정
        self.env = gym.make(ENV)
        
        # 태스크의 상태 변수 수를 구함 (상태변수의 수: 4)
        num_states = self.env.observation_space.shape[0]
        
        # 가능한 행동 수를 구함
        num_actions = self.env.action_space.n
        
        # Agent 객체 생성
        self.agent = Agent(num_states, num_actions)
    
    # 실행
    def run(self):
        
        # 10epoch 동안 버틴 단계 수를 저장, 평균 step을 출력할 때 사용
        epoch_10_list = np.zeros(10)
        
        # 195단계 이상 버틴 epoch 수
        complete_epochs = 0
        
        # 마지막 epoch 여부
        is_epoch_final = False
        
        # 애니메이션을 만드는 데 사용할 이미지를 저장하는 변수
        frames = []
        
        # nb_epoch 만큼 반복
        for epoch in range(nb_epochs):
            
            # 환경 초기화
            observation = self.env.reset()
            
            # observation을 변환 없이 상태를 사용
            state = observation
            
            # Numpy 변수를 파이토치 텐서로 변환
            state = torch.from_numpy(state).type(torch.FloatTensor)
            
            # size 4를 size 1 * 4로 변환
            state = torch.unsqueeze(state, 0)
            
            # 각 epoch에 해당하는 반복
            for step in range(max_steps):
                
                # 마지막 에피소드면 frames에 각 단계의 이미지를 저장
                if is_epoch_final is True:
                    frames.append(self.env.render(mode = 'rgb_array'))
                    
                # 행동 선택
                action = self.agent.get_action(state, epoch)
                
                # 행동 action_t를 실행해 state_t+1, reward_t+1을 계산
                # reward, info는 사용하지 않으므로 under-bar로 처리
                observation_next, _, done, _ = self.env.step(action.item())
                
                # 보상 부여
                if done:
                    
                    # 다음 상태가 없으므로 None
                    state_next = None
                    
                    epoch_10_list = np.hstack( (epoch_10_list[1:], step + 1) )
                    
                    # 200단계를 넘어서거나 일정 각도 이상 기울면 done의 값이 True가 됨
                    if step < 195:
                        
                        # 봉이 쓰러지면 패널티 보상 -1 부여
                        reward = torch.FloatTensor([-1.0])
                        
                        # 195단계 이상 버티면 해당 epoch 성공 처리
                        complete_epochs = 0
                        
                    else:
                        
                        # 쓰러지지 않고 epoch를 끝내면 보상 1 부여
                        reward = torch.FloatTensor([1.0])
                        
                        # epoch 연속 성공 기록을 업데이트
                        complete_epochs = complete_epochs + 1
                        
                else:
                    
                    # epoch 중에는 보상 0 부여
                    reward = torch.FloatTensor([0.0])
                    
                    # observation 결과를 그대로 사용
                    state_next = observation_next
                    
                    # Numpy 변수를 파이토치 텐서로 변환
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    
                    # size 4를 size 1 * 4로 변환
                    state_next = torch.unsqueeze(state_next, 0)
                    
                    
                # 메모리에 경험을 저장
                self.agent.memorize(state, action, state_next, reward)
                    
                # Experience Raplay로 Q 함수를 업데이트
                self.agent.update_Q_function()
                
                # obervation 결과를 업데이트
                state = state_next
                
                # epoch 마무리
                if done:
                    print("{} Epoch was finished after {} time steps | The average step is {}".format(
                        epoch, step + 1, epoch_10_list.mean())
                         )
                    
                    break
                    
            # 마지막 epoch에서 애니메이션을 만들고 저장
            if is_epoch_final is True:
                display_frames_as_gif(frames)
                
                break
                
            # 10연속 이상 성공한 경우(195단계 이상 지속) 조기 종료
            if complete_epochs >= 10:
                print('10연속 이상 성공했습니다.')
                is_epoch_final = True

# %%
# 실행 엔트리 포인트
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Epoch was finished after 19 time steps | The average step is 1.9
# 1 Epoch was finished after 10 time steps | The average step is 2.9
# 2 Epoch was finished after 10 time steps | The average step is 3.9
# 3 Epoch was finished after 10 time steps | The average step is 4.9
# 4 Epoch was finished after 9 time steps | The average step is 5.8
# 5 Epoch was finished after 9 time steps | The average step is 6.7
# 6 Epoch was finished after 10 time steps | The average step is 7.7
# 7 Epoch was finished after 8 time steps | The average step is 8.5
# 8 Epoch was finished after 9 time steps | The average step is 9.4
# 9 Epoch was finished after 10 time steps | The average step is 10.4
# 10 Epoch was finished after 10 time steps | The average step is 9.5
# 11 Epoch was finished after 8 time steps | The average step is 9.3
# 12 Epoch was finished after 9 time steps | The average step is 9.2
# 13 Epoch was finished after 9 time steps | The average step is 9.1
# 14 Epoch was finished after 10 time steps | The average step is 9.2
# <ipython-input-7-e4851e6aa964>:89: UserWarning: indexing with dtype torch.uint8 is now deprecated, please use a dtype torch.bool instead. (Triggered internally at  ..\aten\src\ATen/native/IndexingUtils.h:20.)
#   next_state_values[non_final_mask] = self.model(non_final_next_states).max(1)[0].detach()
# 15 Epoch was finished after 10 time steps | The average step is 9.3
# 16 Epoch was finished after 9 time steps | The average step is 9.2
# 17 Epoch was finished after 10 time steps | The average step is 9.4
# 18 Epoch was finished after 10 time steps | The average step is 9.5
# 19 Epoch was finished after 9 time steps | The average step is 9.4
# 20 Epoch was finished after 10 time steps | The average step is 9.4
# 21 Epoch was finished after 10 time steps | The average step is 9.6
# 22 Epoch was finished after 10 time steps | The average step is 9.7
# 23 Epoch was finished after 14 time steps | The average step is 10.2
# 24 Epoch was finished after 10 time steps | The average step is 10.2
# 25 Epoch was finished after 13 time steps | The average step is 10.5
# 26 Epoch was finished after 9 time steps | The average step is 10.5
# 27 Epoch was finished after 10 time steps | The average step is 10.5
# 28 Epoch was finished after 13 time steps | The average step is 10.8
# 29 Epoch was finished after 11 time steps | The average step is 11.0
# 30 Epoch was finished after 12 time steps | The average step is 11.2
# 31 Epoch was finished after 10 time steps | The average step is 11.2
# 32 Epoch was finished after 9 time steps | The average step is 11.1
# 33 Epoch was finished after 10 time steps | The average step is 10.7
# 34 Epoch was finished after 12 time steps | The average step is 10.9
# 35 Epoch was finished after 10 time steps | The average step is 10.6
# 36 Epoch was finished after 9 time steps | The average step is 10.6
# 37 Epoch was finished after 11 time steps | The average step is 10.7
# 38 Epoch was finished after 10 time steps | The average step is 10.4
# 39 Epoch was finished after 13 time steps | The average step is 10.6
# 40 Epoch was finished after 10 time steps | The average step is 10.4
# 41 Epoch was finished after 15 time steps | The average step is 10.9
# 42 Epoch was finished after 10 time steps | The average step is 11.0
# 43 Epoch was finished after 15 time steps | The average step is 11.5
# 44 Epoch was finished after 13 time steps | The average step is 11.6
# 45 Epoch was finished after 12 time steps | The average step is 11.8
# 46 Epoch was finished after 15 time steps | The average step is 12.4
# 47 Epoch was finished after 16 time steps | The average step is 12.9
# 48 Epoch was finished after 17 time steps | The average step is 13.6
# 49 Epoch was finished after 75 time steps | The average step is 19.8
# 50 Epoch was finished after 14 time steps | The average step is 20.2
# 51 Epoch was finished after 15 time steps | The average step is 20.2
# 52 Epoch was finished after 12 time steps | The average step is 20.4
# 53 Epoch was finished after 11 time steps | The average step is 20.0
# 54 Epoch was finished after 17 time steps | The average step is 20.4
# 55 Epoch was finished after 16 time steps | The average step is 20.8
# 56 Epoch was finished after 15 time steps | The average step is 20.8
# 57 Epoch was finished after 15 time steps | The average step is 20.7
# 58 Epoch was finished after 12 time steps | The average step is 20.2
# 59 Epoch was finished after 17 time steps | The average step is 14.4
# 60 Epoch was finished after 14 time steps | The average step is 14.4
# 61 Epoch was finished after 10 time steps | The average step is 13.9
# 62 Epoch was finished after 12 time steps | The average step is 13.9
# 63 Epoch was finished after 12 time steps | The average step is 14.0
# 64 Epoch was finished after 13 time steps | The average step is 13.6
# 65 Epoch was finished after 11 time steps | The average step is 13.1
# 66 Epoch was finished after 11 time steps | The average step is 12.7
# 67 Epoch was finished after 11 time steps | The average step is 12.3
# 68 Epoch was finished after 13 time steps | The average step is 12.4
# 69 Epoch was finished after 14 time steps | The average step is 12.1
# 70 Epoch was finished after 15 time steps | The average step is 12.2
# 71 Epoch was finished after 12 time steps | The average step is 12.4
# 72 Epoch was finished after 18 time steps | The average step is 13.0
# 73 Epoch was finished after 16 time steps | The average step is 13.4
# 74 Epoch was finished after 19 time steps | The average step is 14.0
# 75 Epoch was finished after 15 time steps | The average step is 14.4
# 76 Epoch was finished after 13 time steps | The average step is 14.6
# 77 Epoch was finished after 19 time steps | The average step is 15.4
# 78 Epoch was finished after 15 time steps | The average step is 15.6
# 79 Epoch was finished after 16 time steps | The average step is 15.8
# 80 Epoch was finished after 16 time steps | The average step is 15.9
# 81 Epoch was finished after 17 time steps | The average step is 16.4
# 82 Epoch was finished after 20 time steps | The average step is 16.6
# 83 Epoch was finished after 20 time steps | The average step is 17.0
# 84 Epoch was finished after 33 time steps | The average step is 18.4
# 85 Epoch was finished after 41 time steps | The average step is 21.0
# 86 Epoch was finished after 24 time steps | The average step is 22.1
# 87 Epoch was finished after 34 time steps | The average step is 23.6
# 88 Epoch was finished after 23 time steps | The average step is 24.4
# 89 Epoch was finished after 22 time steps | The average step is 25.0
# 90 Epoch was finished after 38 time steps | The average step is 27.2
# 91 Epoch was finished after 35 time steps | The average step is 29.0
# 92 Epoch was finished after 45 time steps | The average step is 31.5
# 93 Epoch was finished after 27 time steps | The average step is 32.2
# 94 Epoch was finished after 22 time steps | The average step is 31.1
# 95 Epoch was finished after 60 time steps | The average step is 33.0
# 96 Epoch was finished after 24 time steps | The average step is 33.0
# 97 Epoch was finished after 39 time steps | The average step is 33.5
# 98 Epoch was finished after 26 time steps | The average step is 33.8
# 99 Epoch was finished after 19 time steps | The average step is 33.5
# 100 Epoch was finished after 19 time steps | The average step is 31.6
# 101 Epoch was finished after 33 time steps | The average step is 31.4
# 102 Epoch was finished after 18 time steps | The average step is 28.7
# 103 Epoch was finished after 39 time steps | The average step is 29.9
# 104 Epoch was finished after 53 time steps | The average step is 33.0
# 105 Epoch was finished after 73 time steps | The average step is 34.3
# 106 Epoch was finished after 27 time steps | The average step is 34.6
# 107 Epoch was finished after 38 time steps | The average step is 34.5
# 108 Epoch was finished after 33 time steps | The average step is 35.2
# 109 Epoch was finished after 72 time steps | The average step is 40.5
# 110 Epoch was finished after 64 time steps | The average step is 45.0
# 111 Epoch was finished after 35 time steps | The average step is 45.2
# 112 Epoch was finished after 74 time steps | The average step is 50.8
# 113 Epoch was finished after 64 time steps | The average step is 53.3
# 114 Epoch was finished after 58 time steps | The average step is 53.8
# 115 Epoch was finished after 86 time steps | The average step is 55.1
# 116 Epoch was finished after 50 time steps | The average step is 57.4
# 117 Epoch was finished after 52 time steps | The average step is 58.8
# 118 Epoch was finished after 83 time steps | The average step is 63.8
# 119 Epoch was finished after 35 time steps | The average step is 60.1
# 120 Epoch was finished after 44 time steps | The average step is 58.1
# 121 Epoch was finished after 27 time steps | The average step is 57.3
# 122 Epoch was finished after 24 time steps | The average step is 52.3
# 123 Epoch was finished after 101 time steps | The average step is 56.0
# 124 Epoch was finished after 32 time steps | The average step is 53.4
# 125 Epoch was finished after 38 time steps | The average step is 48.6
# 126 Epoch was finished after 193 time steps | The average step is 62.9
# 127 Epoch was finished after 35 time steps | The average step is 61.2
# 128 Epoch was finished after 32 time steps | The average step is 56.1
# 129 Epoch was finished after 40 time steps | The average step is 56.6
# 130 Epoch was finished after 41 time steps | The average step is 56.3
# 131 Epoch was finished after 61 time steps | The average step is 59.7
# 132 Epoch was finished after 79 time steps | The average step is 65.2
# 133 Epoch was finished after 28 time steps | The average step is 57.9
# 134 Epoch was finished after 79 time steps | The average step is 62.6
# 135 Epoch was finished after 34 time steps | The average step is 62.2
# 136 Epoch was finished after 40 time steps | The average step is 46.9
# 137 Epoch was finished after 73 time steps | The average step is 50.7
# 138 Epoch was finished after 120 time steps | The average step is 59.5
# 139 Epoch was finished after 34 time steps | The average step is 58.9
# 140 Epoch was finished after 76 time steps | The average step is 62.4
# 141 Epoch was finished after 75 time steps | The average step is 63.8
# 142 Epoch was finished after 62 time steps | The average step is 62.1
# 143 Epoch was finished after 36 time steps | The average step is 62.9
# 144 Epoch was finished after 42 time steps | The average step is 59.2
# 145 Epoch was finished after 44 time steps | The average step is 60.2
# 146 Epoch was finished after 68 time steps | The average step is 63.0
# 147 Epoch was finished after 40 time steps | The average step is 59.7
# 148 Epoch was finished after 33 time steps | The average step is 51.0
# 149 Epoch was finished after 78 time steps | The average step is 55.4
# 150 Epoch was finished after 42 time steps | The average step is 52.0
# 151 Epoch was finished after 41 time steps | The average step is 48.6
# 152 Epoch was finished after 66 time steps | The average step is 49.0
# 153 Epoch was finished after 53 time steps | The average step is 50.7
# 154 Epoch was finished after 38 time steps | The average step is 50.3
# 155 Epoch was finished after 53 time steps | The average step is 51.2
# 156 Epoch was finished after 49 time steps | The average step is 49.3
# 157 Epoch was finished after 32 time steps | The average step is 48.5
# 158 Epoch was finished after 50 time steps | The average step is 50.2
# 159 Epoch was finished after 64 time steps | The average step is 48.8
# 160 Epoch was finished after 71 time steps | The average step is 51.7
# 161 Epoch was finished after 120 time steps | The average step is 59.6
# 162 Epoch was finished after 85 time steps | The average step is 61.5
# 163 Epoch was finished after 47 time steps | The average step is 60.9
# 164 Epoch was finished after 82 time steps | The average step is 65.3
# 165 Epoch was finished after 50 time steps | The average step is 65.0
# 166 Epoch was finished after 61 time steps | The average step is 66.2
# 167 Epoch was finished after 85 time steps | The average step is 71.5
# 168 Epoch was finished after 194 time steps | The average step is 85.9
# 169 Epoch was finished after 74 time steps | The average step is 86.9
# 170 Epoch was finished after 62 time steps | The average step is 86.0
# 171 Epoch was finished after 67 time steps | The average step is 80.7
# 172 Epoch was finished after 58 time steps | The average step is 78.0
# 173 Epoch was finished after 87 time steps | The average step is 82.0
# 174 Epoch was finished after 81 time steps | The average step is 81.9
# 175 Epoch was finished after 76 time steps | The average step is 84.5
# 176 Epoch was finished after 65 time steps | The average step is 84.9
# 177 Epoch was finished after 106 time steps | The average step is 87.0
# 178 Epoch was finished after 99 time steps | The average step is 77.5
# 179 Epoch was finished after 67 time steps | The average step is 76.8
# 180 Epoch was finished after 65 time steps | The average step is 77.1
# 181 Epoch was finished after 200 time steps | The average step is 90.4
# 182 Epoch was finished after 60 time steps | The average step is 90.6
# 183 Epoch was finished after 53 time steps | The average step is 87.2
# 184 Epoch was finished after 200 time steps | The average step is 99.1
# 185 Epoch was finished after 34 time steps | The average step is 94.9
# 186 Epoch was finished after 51 time steps | The average step is 93.5
# 187 Epoch was finished after 45 time steps | The average step is 87.4
# 188 Epoch was finished after 178 time steps | The average step is 95.3
# 189 Epoch was finished after 52 time steps | The average step is 93.8
# 190 Epoch was finished after 68 time steps | The average step is 94.1
# 191 Epoch was finished after 63 time steps | The average step is 80.4
# 192 Epoch was finished after 110 time steps | The average step is 85.4
# 193 Epoch was finished after 46 time steps | The average step is 84.7
# 194 Epoch was finished after 89 time steps | The average step is 73.6
# 195 Epoch was finished after 62 time steps | The average step is 76.4
# 196 Epoch was finished after 72 time steps | The average step is 78.5
# 197 Epoch was finished after 186 time steps | The average step is 92.6
# 198 Epoch was finished after 157 time steps | The average step is 90.5
# 199 Epoch was finished after 62 time steps | The average step is 91.5
# 200 Epoch was finished after 72 time steps | The average step is 91.9
# 201 Epoch was finished after 200 time steps | The average step is 105.6
# 202 Epoch was finished after 89 time steps | The average step is 103.5
# 203 Epoch was finished after 139 time steps | The average step is 112.8
# 204 Epoch was finished after 159 time steps | The average step is 119.8
# 205 Epoch was finished after 175 time steps | The average step is 131.1
# 206 Epoch was finished after 137 time steps | The average step is 137.6
# 207 Epoch was finished after 191 time steps | The average step is 138.1
# 208 Epoch was finished after 200 time steps | The average step is 142.4
# 209 Epoch was finished after 200 time steps | The average step is 156.2
# 210 Epoch was finished after 120 time steps | The average step is 161.0
# 211 Epoch was finished after 110 time steps | The average step is 152.0
# 212 Epoch was finished after 169 time steps | The average step is 160.0
# 213 Epoch was finished after 147 time steps | The average step is 160.8
# 214 Epoch was finished after 200 time steps | The average step is 164.9
# 215 Epoch was finished after 200 time steps | The average step is 167.4
# 216 Epoch was finished after 200 time steps | The average step is 173.7
# 217 Epoch was finished after 143 time steps | The average step is 168.9
# 218 Epoch was finished after 138 time steps | The average step is 162.7
# 219 Epoch was finished after 200 time steps | The average step is 162.7
# 220 Epoch was finished after 137 time steps | The average step is 164.4
# 221 Epoch was finished after 99 time steps | The average step is 163.3
# 222 Epoch was finished after 200 time steps | The average step is 166.4
# 223 Epoch was finished after 200 time steps | The average step is 171.7
# 224 Epoch was finished after 200 time steps | The average step is 171.7
# 225 Epoch was finished after 67 time steps | The average step is 158.4
# 226 Epoch was finished after 159 time steps | The average step is 154.3
# 227 Epoch was finished after 80 time steps | The average step is 148.0
# 228 Epoch was finished after 129 time steps | The average step is 147.1
# 229 Epoch was finished after 77 time steps | The average step is 134.8
# 230 Epoch was finished after 53 time steps | The average step is 126.4
# 231 Epoch was finished after 45 time steps | The average step is 121.0
# 232 Epoch was finished after 85 time steps | The average step is 109.5
# 233 Epoch was finished after 62 time steps | The average step is 95.7
# 234 Epoch was finished after 48 time steps | The average step is 80.5
# 235 Epoch was finished after 32 time steps | The average step is 77.0
# 236 Epoch was finished after 37 time steps | The average step is 64.8
# 237 Epoch was finished after 31 time steps | The average step is 59.9
# 238 Epoch was finished after 43 time steps | The average step is 51.3
# 239 Epoch was finished after 37 time steps | The average step is 47.3
# 240 Epoch was finished after 33 time steps | The average step is 45.3
# 241 Epoch was finished after 58 time steps | The average step is 46.6
# 242 Epoch was finished after 53 time steps | The average step is 43.4
# 243 Epoch was finished after 71 time steps | The average step is 44.3
# 244 Epoch was finished after 64 time steps | The average step is 45.9
# 245 Epoch was finished after 50 time steps | The average step is 47.7
# 246 Epoch was finished after 48 time steps | The average step is 48.8
# 247 Epoch was finished after 50 time steps | The average step is 50.7
# 248 Epoch was finished after 63 time steps | The average step is 52.7
# 249 Epoch was finished after 53 time steps | The average step is 54.3
# 250 Epoch was finished after 70 time steps | The average step is 58.0
# 251 Epoch was finished after 82 time steps | The average step is 60.4
# 252 Epoch was finished after 76 time steps | The average step is 62.7
# 253 Epoch was finished after 134 time steps | The average step is 69.0
# 254 Epoch was finished after 104 time steps | The average step is 73.0
# 255 Epoch was finished after 200 time steps | The average step is 88.0
# 256 Epoch was finished after 200 time steps | The average step is 103.2
# 257 Epoch was finished after 137 time steps | The average step is 111.9
# 258 Epoch was finished after 91 time steps | The average step is 114.7
# 259 Epoch was finished after 55 time steps | The average step is 114.9
# 260 Epoch was finished after 49 time steps | The average step is 112.8
# 261 Epoch was finished after 49 time steps | The average step is 109.5
# 262 Epoch was finished after 48 time steps | The average step is 106.7
# 263 Epoch was finished after 34 time steps | The average step is 96.7
# 264 Epoch was finished after 26 time steps | The average step is 88.9
# 265 Epoch was finished after 24 time steps | The average step is 71.3
# 266 Epoch was finished after 24 time steps | The average step is 53.7
# 267 Epoch was finished after 19 time steps | The average step is 41.9
# 268 Epoch was finished after 14 time steps | The average step is 34.2
# 269 Epoch was finished after 13 time steps | The average step is 30.0
# 270 Epoch was finished after 14 time steps | The average step is 26.5
# 271 Epoch was finished after 11 time steps | The average step is 22.7
# 272 Epoch was finished after 10 time steps | The average step is 18.9
# 273 Epoch was finished after 8 time steps | The average step is 16.3
# 274 Epoch was finished after 10 time steps | The average step is 14.7
# 275 Epoch was finished after 10 time steps | The average step is 13.3
# 276 Epoch was finished after 9 time steps | The average step is 11.8
# 277 Epoch was finished after 9 time steps | The average step is 10.8
# 278 Epoch was finished after 8 time steps | The average step is 10.2
# 279 Epoch was finished after 9 time steps | The average step is 9.8
# 280 Epoch was finished after 9 time steps | The average step is 9.3
# 281 Epoch was finished after 10 time steps | The average step is 9.2
# 282 Epoch was finished after 8 time steps | The average step is 9.0
# 283 Epoch was finished after 8 time steps | The average step is 9.0
# 284 Epoch was finished after 9 time steps | The average step is 8.9
# 285 Epoch was finished after 10 time steps | The average step is 8.9
# 286 Epoch was finished after 9 time steps | The average step is 8.9
# 287 Epoch was finished after 9 time steps | The average step is 8.9
# 288 Epoch was finished after 10 time steps | The average step is 9.1
# 289 Epoch was finished after 9 time steps | The average step is 9.1
# 290 Epoch was finished after 10 time steps | The average step is 9.2
# 291 Epoch was finished after 9 time steps | The average step is 9.1
# 292 Epoch was finished after 8 time steps | The average step is 9.1
# 293 Epoch was finished after 10 time steps | The average step is 9.3
# 294 Epoch was finished after 9 time steps | The average step is 9.3
# 295 Epoch was finished after 10 time steps | The average step is 9.3
# 296 Epoch was finished after 9 time steps | The average step is 9.3
# 297 Epoch was finished after 9 time steps | The average step is 9.3
# 298 Epoch was finished after 11 time steps | The average step is 9.4
# 299 Epoch was finished after 10 time steps | The average step is 9.5
# 300 Epoch was finished after 9 time steps | The average step is 9.4
# 301 Epoch was finished after 9 time steps | The average step is 9.4
# 302 Epoch was finished after 9 time steps | The average step is 9.5
# 303 Epoch was finished after 8 time steps | The average step is 9.3
# 304 Epoch was finished after 9 time steps | The average step is 9.3
# 305 Epoch was finished after 10 time steps | The average step is 9.3
# 306 Epoch was finished after 9 time steps | The average step is 9.3
# 307 Epoch was finished after 10 time steps | The average step is 9.4
# 308 Epoch was finished after 10 time steps | The average step is 9.3
# 309 Epoch was finished after 10 time steps | The average step is 9.3
# 310 Epoch was finished after 9 time steps | The average step is 9.3
# 311 Epoch was finished after 8 time steps | The average step is 9.2
# 312 Epoch was finished after 9 time steps | The average step is 9.2
# 313 Epoch was finished after 9 time steps | The average step is 9.3
# 314 Epoch was finished after 9 time steps | The average step is 9.3
# 315 Epoch was finished after 10 time steps | The average step is 9.3
# 316 Epoch was finished after 10 time steps | The average step is 9.4
# 317 Epoch was finished after 10 time steps | The average step is 9.4
# 318 Epoch was finished after 10 time steps | The average step is 9.4
# 319 Epoch was finished after 11 time steps | The average step is 9.5
# 320 Epoch was finished after 9 time steps | The average step is 9.5
# 321 Epoch was finished after 10 time steps | The average step is 9.7
# 322 Epoch was finished after 10 time steps | The average step is 9.8
# 323 Epoch was finished after 9 time steps | The average step is 9.8
# 324 Epoch was finished after 10 time steps | The average step is 9.9
# 325 Epoch was finished after 8 time steps | The average step is 9.7
# 326 Epoch was finished after 8 time steps | The average step is 9.5
# 327 Epoch was finished after 11 time steps | The average step is 9.6
# 328 Epoch was finished after 9 time steps | The average step is 9.5
# 329 Epoch was finished after 11 time steps | The average step is 9.5
# 330 Epoch was finished after 10 time steps | The average step is 9.6
# 331 Epoch was finished after 9 time steps | The average step is 9.5
# 332 Epoch was finished after 10 time steps | The average step is 9.5
# 333 Epoch was finished after 11 time steps | The average step is 9.7
# 334 Epoch was finished after 9 time steps | The average step is 9.6
# 335 Epoch was finished after 10 time steps | The average step is 9.8
# 336 Epoch was finished after 9 time steps | The average step is 9.9
# 337 Epoch was finished after 8 time steps | The average step is 9.6
# 338 Epoch was finished after 9 time steps | The average step is 9.6
# 339 Epoch was finished after 10 time steps | The average step is 9.5
# 340 Epoch was finished after 9 time steps | The average step is 9.4
# 341 Epoch was finished after 10 time steps | The average step is 9.5
# 342 Epoch was finished after 9 time steps | The average step is 9.4
# 343 Epoch was finished after 9 time steps | The average step is 9.2
# 344 Epoch was finished after 10 time steps | The average step is 9.3
# 345 Epoch was finished after 9 time steps | The average step is 9.2
# 346 Epoch was finished after 11 time steps | The average step is 9.4
# 347 Epoch was finished after 9 time steps | The average step is 9.5
# 348 Epoch was finished after 10 time steps | The average step is 9.6
# 349 Epoch was finished after 14 time steps | The average step is 10.0
# 350 Epoch was finished after 13 time steps | The average step is 10.4
# 351 Epoch was finished after 20 time steps | The average step is 11.4
# 352 Epoch was finished after 24 time steps | The average step is 12.9
# 353 Epoch was finished after 37 time steps | The average step is 15.7
# 354 Epoch was finished after 98 time steps | The average step is 24.5
# 355 Epoch was finished after 107 time steps | The average step is 34.3
# 356 Epoch was finished after 200 time steps | The average step is 53.2
# 357 Epoch was finished after 183 time steps | The average step is 70.6
# 358 Epoch was finished after 200 time steps | The average step is 89.6
# 359 Epoch was finished after 200 time steps | The average step is 108.2
# 360 Epoch was finished after 200 time steps | The average step is 126.9
# 361 Epoch was finished after 200 time steps | The average step is 144.9
# 362 Epoch was finished after 200 time steps | The average step is 162.5
# 363 Epoch was finished after 200 time steps | The average step is 178.8
# 364 Epoch was finished after 200 time steps | The average step is 189.0
# 365 Epoch was finished after 200 time steps | The average step is 198.3
# 366 Epoch was finished after 200 time steps | The average step is 198.3
# 367 Epoch was finished after 200 time steps | The average step is 200.0
# 10연속 이상 성공했습니다.
# MovieWriter ffmpeg unavailable; using Pillow instead.
# 368 Epoch was finished after 185 time steps | The average step is 198.5
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\JSAnimation\html_writer.py:281: MatplotlibDeprecationWarning:
# The 'clear_temp' parameter of setup() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. If any parameter follows 'clear_temp', they should be passed as keyword, not positionally.
#   super(HTMLWriter, self).setup(fig, outfile, dpi,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-301b0b9439fe> in <module>
#       1 # 실행 엔트리 포인트
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# <ipython-input-8-2a71a8f3dc36> in run(self)
#     123             # 마지막 epoch에서 애니메이션을 만들고 저장
#     124             if is_epoch_final is True:
# --> 125                 display_frames_as_gif(frames)
#     126
#     127                 break
#
# <ipython-input-2-3866cfe4284f> in display_frames_as_gif(frames)
#      24
#      25     anim.save('CartPole_Q-learning_DQN.gif')
# ---> 26     display(display_animation(anim, default_mode = 'loop'))
#
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\JSAnimation\IPython_display.py in display_animation(anim, **kwargs)
#      84     """Display the animation with an IPython HTML object"""
#      85     from IPython.display import HTML
# ---> 86     return HTML(anim_to_html(anim, **kwargs))
#      87
#      88
#
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\JSAnimation\IPython_display.py in anim_to_html(anim, fps, embed_frames, default_mode)
#      72         #with tempfile.NamedTemporaryFile(suffix='.html') as f:
#      73         with _NameOnlyTemporaryFile(suffix='.html') as f:
# ---> 74             anim.save(f.name,  writer=HTMLWriter(fps=fps,
#      75                                                  embed_frames=embed_frames,
#      76                                                  default_mode=default_mode))
#
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1135                         progress_callback(frame_number, total_frames)
#    1136                         frame_number += 1
# -> 1137                 writer.grab_frame(**savefig_kwargs)
#    1138
#    1139     def _step(self, *args):
#
# c:\users\choih\appdata\local\programs\python\python38\lib\contextlib.py in __exit__(self, type, value, traceback)
#     118         if type is None:
#     119             try:
# --> 120                 next(self.gen)
#     121             except StopIteration:
#     122                 return False
#
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     251             yield self
#     252         finally:
# --> 253             self.finish()
#     254
#     255
#
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\matplotlib\animation.py in finish(self)
#     515         # Call run here now that all frame grabbing is done. All temp files
#     516         # are available to be assembled.
# --> 517         self._run()
#     518         MovieWriter.finish(self)  # Will call clean-up
#     519
#
# c:\users\choih\appdata\local\programs\python\python38\lib\site-packages\JSAnimation\html_writer.py in _run(self)
#     321             of.write(JS_INCLUDE)
#     322             of.write(DISPLAY_TEMPLATE.format(id=self.new_id(),
# --> 323                                              Nframes=len(self._temp_names),
#     324                                              fill_frames=fill_frames,
#     325                                              interval=interval,
#
# AttributeError: 'HTMLWriter' object has no attribute '_temp_names'
